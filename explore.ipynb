# %% [markdown]
# ## 1. Clean your Datasets
#
# For the first part of your project, you will apply the same data cleaning steps to your "data/control.txt" and "data/treatment.txt" files. By the end of this step, you should have two lists of floats that match the numbers you have in each respective file.
#
# You will implement your `clean_data` function in your `cleaner.py` module and import the module in the code-block below.

# %%
# TODO: import all the packages that you will need for this notebook here
import cleaner
import statistics as stats
import matplotlib.pyplot as plt

# %%
# TODO: read your text files into your code using file I/O

control_file = open("data/control.txt")
treatment_file = open("data/treatment.txt")

control_data = control_file.readlines()
treatment_data = treatment_file.readlines()

# TODO: clean both list objects that you created above using the 'clean_data' function
clean_control = cleaner.clean_data(control_data)
clean_treatment = cleaner.clean_data(treatment_data)

print(f'Control group max: {max(clean_control)}')
print(f'Treatment group max: {max(clean_treatment)}')


print("Clean control data: ", clean_control)
print("Clean Treatment data: ", clean_treatment)
# Out:
# Control group max: 21.21
# Treatment group max: 22.85
# ...

# %% [markdown]
# ## 2. Explore your Datasets
#
# Now that you have your list objects created and cleaned, let's explore the descriptive statistics of these two files and make subsequent observations on our data.

# %%
# TODO: Calculate the standard deviation of both the control and treatment group

control_stdev = stats.stdev(clean_control)
treatment_stdev = stats.stdev(clean_treatment)

# TODO: print your findings
print(f'Control standard deviation = {round(control_stdev, 2)}')
print(f'Treatment standard deviation = {round(treatment_stdev,2)}')
# Out:
# Control standard deviation = 3.26
# Treatment standard deviation = 2.09

# %%
# TODO: Calculate the mean of both the control and treatment group
control_avg = stats.mean(clean_control)
treatment_avg = stats.mean(clean_treatment)

# TODO: print your findings
print(f'Control average = {round(control_avg, 2)}')
print(f'Treatment average = {round(treatment_avg, 2)}')
# Out:
# Control average = 12.45
# Treatment average = 16.8

# %%
# TODO: Are there any outliers in your control group? (use 2 * stdev to find these outliers)
outliers_control = []
count = 0
for outlier in clean_control:
    if outlier < control_avg - 2*control_stdev or outlier > control_avg + 2*control_stdev:
        outliers_control.append(outlier)
        count += 1

print(f'Outliers count: {count}')
print(outliers_control)
# Out:
# Outliers count: 20
# [5.92, 4.36, 4.21, 20.2, 3.69, 3.83, 21.21, 5.07, 4.87, 5.28, 5.75, 20.18, 20.95, 4.12, 19.21, 5.51, 4.01, 20.57, 20.72, 3.71]

# %%
# TODO: Are there any outliers in your treatment group?
outliers_treatment = []
count = 0
for outlier in clean_treatment:
    if outlier < treatment_avg - 2*treatment_stdev or outlier > treatment_avg + 2*treatment_stdev:
        outliers_treatment.append(outlier)
        count += 1

print(f'Outliers count: {count}')
print(outliers_treatment)
# Out:
# Outliers count: 20
# [21.17, 10.34, 21.07, 11.54, 21.66, 22.11, 12.02, 12.41, 11.35, 22.85, 21.49, 11.99, 21.57, 21.76, 12.54, 12.53, 12.34, 12.32, 21.42, 10.33]

# %% [markdown]
# ## 3. Create Data Visualizations
#
# For this final step, generate data visualizations to view the dispersion of both of your groups.
#
# Make sure that the two visualizations you create are on the same figure.

# %%
# TODO: create a data visualization to view differences in dispersion and mean
fig, ax = plt.subplots()

ax.set_title('Control Group Vs Treatment Group Viewing Times')
ax.set_xlabel('Minutes')
ax.set_ylabel('Participants')

ax.hist(clean_control, bins = 25, color = 'blue', edgecolor= 'pink',alpha = 0.6)
ax.hist(clean_treatment, bins = 25, color = 'purple', edgecolor= 'purple',alpha = 0.8)
# Out:
# (array([ 2.,  0.,  2.,  3.,  5., 12., 15., 22., 28., 35., 38., 43., 46.,
#         46., 51., 35., 32., 26., 22., 18.,  8.,  4.,  5.,  1.,  1.]),
#  array([10.33  , 10.8308, 11.3316, 11.8324, 12.3332, 12.834 , 13.3348,
#         13.8356, 14.3364, 14.8372, 15.338 , 15.8388, 16.3396, 16.8404,
#         17.3412, 17.842 , 18.3428, 18.8436, 19.3444, 19.8452, 20.346 ,
#         20.8468, 21.3476, 21.8484, 22.3492, 22.85  ]),
#  <BarContainer object of 25 artists>)

# %% [markdown]
# ## 4. Your Data Findings
#
# What did you discover about your two datasets? Which group has the highest viewing time? What would you want to investigate next?

# %% [markdown]
# The average between the control group data and treatment group data did differ by a few minutes. An interest find was that the treatment group actually had the higher average viewing time by 4 minutes even though they had over 70% fewer words on each slide. The standard deviation was smaller for the treatment group meaning most of the group perfromed similarly. The treatment group also had the higher maximum number, 22.85 minutes; the max for the control group is 21.21 minutes. With this information, it is safe to cocnlude that fewer words on a slide does not directly cause shorter viewer time. To further explore the effectiveness of the different slides I would create a quiz based on thee information presented on the slides. The same quiz would be passed out to each individual and then I would start exploring that data set to see which slides helped participants retain more information. I would also explore if the viewing time had any correlation with the quiz scores.

# %% [markdown]
# ## Context Setting
# Establish what was already done before this A/B test. What are some questions you
# can ask to get more information on what has already been measured, analyzed, or
# attempted? List them below...
# * What is the reason for this reasearch?
# * What is the ideal amount of slides we are reaching for?
# * Is there a preferred viewing time?
# * How was this data aquired?
#
# ## Goal Alignment
# Align with stakeholders on what success means before interpreting any numbers.
# * How are these findings intended to be used?
#
#
# ## Define Over-performance
# Consider what it would mean if the treatment dramatically exceeded expectations.
# * What are the next steps if the results are drastically differ from the expectation?
#
# ## Data Sourcing
# Reflect on what other data sources you can use to answer your stakeholders
# exploratory goals.
# *
